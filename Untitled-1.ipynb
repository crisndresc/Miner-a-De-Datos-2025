# %%
print('Hola mundo') 
#Trabajo con otro ambiente/entorno de trabajo
# Out:
# Hola mundo

# %% [markdown]
# Normalizacion en procesamiento
# Predecir de salida para clientes telefonicos
# minimos cuadrados ==> Regresion

# %%
import pandas as pd

# %%
'hola'+str(4)
# Out:
# 'hola4'

# %%
int('2')+2
# Out:
# 4

# %%
len('hola')
# Out:
# 4

# %% [markdown]
# #!pip install pandas

# %%
import pandas as pd 
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df = pd.read_csv(r"C:\Users\crist\OneDrive\Escritorio\mineria de datos\nations.csv")
df
# Out:
#      Unnamed: 0          country   region           gdp     school  \
# 0             1          Algeria   Africa   7300.399902   6.716667
# 1             2            Benin   Africa   1338.800049   3.100000
# 2             3         Botswana   Africa  12307.400391   8.600000
# 3             4     Burkina Faso   Africa   1063.400024   1.300000
# 4             5          Burundi   Africa    349.200012   2.483333
# ..          ...              ...      ...           ...        ...
# 189         190            Samoa  Oceania   4012.600098  10.300000
# 190         191  Solomon Islands  Oceania   2249.199951   4.500000
# 191         192            Tonga  Oceania   4072.199951  10.133333
# 192         193           Tuvalu  Oceania           NaN        NaN
# 193         194          Vanuatu  Oceania   3809.800049   6.700000
#
#          adfert  chldmort       life       pop      urban  femlab   literacy  \
# 0      7.300000     34.75  72.316666  34172236  64.933334  0.4522  72.599998
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       country  region           gdp    school      adfert  \
# 0           1       Algeria  Africa   7300.399902  6.716667    7.300000
# 1           2         Benin  Africa   1338.800049  3.100000  111.699997
# 2           3      Botswana  Africa  12307.400391  8.600000   52.099998
# 3           4  Burkina Faso  Africa   1063.400024  1.300000  124.800003
# 4           5       Burundi  Africa    349.200012  2.483333   18.600000
#
#    chldmort       life       pop      urban  femlab   literacy   co2  \
# 0     34.75  72.316666  34172236  64.933334  0.4522  72.599998  15.0
# 1    122.75  54.733334   8237634  41.000000  0.8482  41.700001   1.2
# 2     60.25  52.250000   1941233  59.250000  0.8870  84.099998   9.2
# 3    170.50  53.783333  15308383  23.583334  0.8584  23.600000   0.2
# 4    168.50  48.866665   7821783  10.250000  1.0344  66.599998   0.1
#
#         gini
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  33.299999

# %%
dfedit"region".valuegini

# %% [markdown]
# .mean() promedio

# %%
import matplotlib.pyplot as plt

# %%
dfedit['gini'].plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dfedit['gini'].plot(kind='hist')
#
# NameError: name 'dfedit' is not defined

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 621.2 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/9.8 MB 621.2 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/9.8 MB 610.3 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/9.8 MB 610.3 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/9.8 MB 553.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.0/9.8 MB 553.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.0/9.8 MB 553.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.0/9.8 MB 553.0 kB/s eta 0:00:16
# ...

# %%
modelo.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 modelo.summary()
#
# NameError: name 'modelo' is not defined

# %%
#axvline, linea vertical en el grafico

# %%
np.where(dfedit)

# %%
df.drop()

# %%
df.

# %%
#Esemana-1
#Programacion en arduino lenguaje C, bsucar objetivos, que tipo de proyecto puedo hacer con arduino¿?
#describir que haced cada codigo 
#estructura 
#biblioteca
#estudiar parte teorica de programar 
#ides del proyecto semana 15-16 (final)
#Preparar un buen proyecto== ¿Puede ser un motor de induccion con arduino?
#sofware de bajo nivel (no se vee, lenguaje C,python, va directamente al intergrando, control de temperatura) y alto nivel(Vee nuestros ojos)
#harware periferico
#Sistema embebido
#

# %% [markdown]
# #microprocesador (blackberry), microprogramador

# %%
#integrado, familia
#microcontrolador PIC:industria
#STM32 micocontrolador, internet
#microcontroladores de la familia ESP8266 Y ESP32, SE PORGRAMA CON LENGUAJE C, PYTHON, otro tipo de programador.
#Microprocesadores x86; c++,python, java, lenguaje C, Procesadores x86.
#nuevo microchip de microsoft, chipcuantico
#analogico y digitales
#programa: microprocesador,microcontrolador

# %%
#coe::blocks
#visual c++:
#Xcode
